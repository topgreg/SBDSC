# %% [markdown]
# #pip install spotipy

# %% [markdown]
# spotipy documentation
# https://spotipy.readthedocs.io/en/latest/#installation
#
# google sheet with links to top song playlists: https://docs.google.com/spreadsheets/d/10gRoHKIB1RFfxSvb83gzYkV33x5eMMI1RZoXSamFwPI/edit#gid=824975682
#
# github for project that I referenced to pull data: https://github.com/ekatnic/SpotifyApiExploration/blob/master/Spotify_Generate_Tracks.ipynb
#
# Proposal: https://docs.google.com/document/d/1rRzJV0hOaNMsBIjji8v1Cv8C3QUuZ6lUvYokZ5dif-A/edit

# %%
# Import relevant libraries and packages.
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing 
import warnings
from scipy import stats

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
#import sys

credentials = []
f = open('credentials.txt', 'r')
for line in f:
    #add line to credentials list (remove trailing whitespace characters)
    credentials.append(line.rstrip())

# create Spotify object with credentials
client_credentials_manager = SpotifyClientCredentials(credentials[0], credentials[1])
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# topLink2021 = "https://open.spotify.com/playlist/5GhQiRkGuqzpWZSE7OU4Se"
# topLink2020 = "https://open.spotify.com/playlist/2fmTTbBkXi8pewbUvG3CeZ"
# topLink2019 = "https://open.spotify.com/playlist/37i9dQZF1DWVRSukIED0e9"
# topLink2018 = "https://open.spotify.com/playlist/37i9dQZF1DXe2bobNYDtW8"
# topLink2017 = "https://open.spotify.com/playlist/37i9dQZF1DWTE7dVUebpUW"
# topLink2016 = "https://open.spotify.com/playlist/37i9dQZF1DX8XZ6AUo9R4R"
# topLink2015 = "https://open.spotify.com/playlist/37i9dQZF1DX9ukdrXQLJGZ"
# topLink2014 = "https://open.spotify.com/playlist/37i9dQZF1DX0h0QnLkMBl4"
# topLink2013 = "https://open.spotify.com/playlist/37i9dQZF1DX3Sp0P28SIer"
# topLink2012 = "https://open.spotify.com/playlist/37i9dQZF1DX0yEZaMOXna3"
# topLink2011 = "https://open.spotify.com/playlist/37i9dQZF1DXcagnSNtrGuJ"
# topLink2010 = "https://open.spotify.com/playlist/37i9dQZF1DXc6IFF23C9jj"
# topLink2009 = "https://open.spotify.com/playlist/37i9dQZF1DX4UkKv8ED8jp"
# topLink2008 = "https://open.spotify.com/playlist/37i9dQZF1DWYuGZUE4XQXm"
# topLink2007 = "https://open.spotify.com/playlist/37i9dQZF1DX3j9EYdzv2N9"
# topLink2006 = "https://open.spotify.com/playlist/37i9dQZF1DX1vSJnMeoy3V"
# topLink2005 = "https://open.spotify.com/playlist/37i9dQZF1DWWzQTBs5BHX9"
# topLink2004 = "https://open.spotify.com/playlist/37i9dQZF1DWTWdbR13PQYH"
# topLink2003 = "https://open.spotify.com/playlist/37i9dQZF1DXaW8fzPh9b08"
# topLink2002 = "https://open.spotify.com/playlist/37i9dQZF1DX0P7PzzKwEKl"
# topLink2001 = "https://open.spotify.com/playlist/37i9dQZF1DX9Ol4tZWPH6V"
# topLink2000 = "https://open.spotify.com/playlist/37i9dQZF1DWUZv12GM5cFk"
# allLinks = [topLink2000, topLink2001, topLink2002, topLink2003, topLink2004, topLink2005, topLink2006, topLink2007, topLink2008, topLink2009, topLink2010, topLink2011, topLink2012, topLink2013, topLink2014, topLink2015, topLink2016, topLink2017, topLink2018, topLink2019, topLink2020, topLink2021]
# allLinks2 = ["https://open.spotify.com/playlist/5GhQiRkGuqzpWZSE7OU4Se", "https://open.spotify.com/playlist/2fmTTbBkXi8pewbUvG3CeZ"]
# allLinks3 = [topLink2018, topLink2019, topLink2020, topLink2021]

# %% [markdown]
# #YearDictionary = {"https://open.spotify.com/playlist/5GhQiRkGuqzpWZSE7OU4Se": 2021, "https://open.spotify.com/playlist/2fmTTbBkXi8pewbUvG3CeZ": 2020, "https://open.spotify.com/playlist/37i9dQZF1DWVRSukIED0e9": 2019}
# YearDictionary = {"https://open.spotify.com/playlist/5GhQiRkGuqzpWZSE7OU4Se": 2021, "https://open.spotify.com/playlist/2fmTTbBkXi8pewbUvG3CeZ": 2020, "https://open.spotify.com/playlist/37i9dQZF1DWVRSukIED0e9": 2019, "https://open.spotify.com/playlist/37i9dQZF1DXe2bobNYDtW8": 2018, "https://open.spotify.com/playlist/37i9dQZF1DWTE7dVUebpUW": 2017, "https://open.spotify.com/playlist/37i9dQZF1DX8XZ6AUo9R4R": 2016, "https://open.spotify.com/playlist/37i9dQZF1DX9ukdrXQLJGZ": 2015, "https://open.spotify.com/playlist/37i9dQZF1DX0h0QnLkMBl4": 2014, "https://open.spotify.com/playlist/37i9dQZF1DX3Sp0P28SIer": 2013, "https://open.spotify.com/playlist/37i9dQZF1DX0yEZaMOXna3": 2012, "https://open.spotify.com/playlist/37i9dQZF1DXcagnSNtrGuJ": 2011, "https://open.spotify.com/playlist/37i9dQZF1DXc6IFF23C9jj": 2010, "https://open.spotify.com/playlist/37i9dQZF1DX4UkKv8ED8jp": 2009, "https://open.spotify.com/playlist/37i9dQZF1DWYuGZUE4XQXm": 2008, "https://open.spotify.com/playlist/37i9dQZF1DX3j9EYdzv2N9": 2007, "https://open.spotify.com/playlist/37i9dQZF1DX1vSJnMeoy3V": 2006, "https://open.spotify.com/playlist/37i9dQZF1DWWzQTBs5BHX9": 2005, "https://open.spotify.com/playlist/37i9dQZF1DWTWdbR13PQYH": 2004, "https://open.spotify.com/playlist/37i9dQZF1DXaW8fzPh9b08": 2003, "https://open.spotify.com/playlist/37i9dQZF1DX0P7PzzKwEKl": 2002, "https://open.spotify.com/playlist/37i9dQZF1DX9Ol4tZWPH6V": 2001, "https://open.spotify.com/playlist/37i9dQZF1DWUZv12GM5cFk": 2000}

# %%
Artist_detail = pd.read_csv("/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/artists.csv")
# Out:
# /var/folders/rc/20gvvbw10mg1xrcm82p5g4tm0000gn/T/ipykernel_26723/1745976627.py:1: DtypeWarning: Columns (2,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   Artist_detail = pd.read_csv("/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/artists.csv")

# %%
Artist_detail.head()
# Out:
#                                    mbid              artist_mb  \
# 0  cc197bad-dc9c-440d-a5b5-d52ba2e14234               Coldplay
# 1  a74b1b7f-71a5-4011-9441-d0b5e4122711              Radiohead
# 2  8bfac288-ccc5-448d-9573-c33ea2aa5c30  Red Hot Chili Peppers
# 3  73e5e69d-3554-40d8-8516-00cb38737a1c                Rihanna
# 4  b95ce3ff-3d05-4e87-9e01-c97b66af13d4                 Eminem
#
#            artist_lastfm      country_mb           country_lastfm  \
# 0               Coldplay  United Kingdom           United Kingdom
# 1              Radiohead  United Kingdom           United Kingdom
# 2  Red Hot Chili Peppers   United States            United States
# 3                Rihanna   United States  Barbados; United States
# 4                 Eminem   United States            United States
#
#                                              tags_mb  \
# 0  rock; pop; alternative rock; british; uk; brit...
# 1  rock; electronic; alternative rock; british; g...
# 2  rock; alternative rock; 80s; 90s; rap; metal; ...
# 3  pop; dance; hip hop; reggae; contemporary r b;...
# 4  turkish; rap; american; hip-hop; hip hop; hiph...
#
#                                          tags_lastfm  listeners_lastfm  \
# 0  rock; alternative; britpop; alternative rock; ...         5381567.0
# 1  alternative; alternative rock; rock; indie; el...         4732528.0
# 2  rock; alternative rock; alternative; Funk Rock...         4620835.0
# 3  pop; rnb; female vocalists; dance; Hip-Hop; Ri...         4558193.0
# 4  rap; Hip-Hop; Eminem; hip hop; pop; american; ...         4517997.0
#
#    scrobbles_lastfm  ambiguous_artist
# 0       360111850.0             False
# 1       499548797.0             False
# 2       293784041.0             False
# 3       199248986.0             False
# 4       199507511.0             False

# %%
#Artist_detail = Artist_detail.rename(columns = {'artist_mb':'artist_name'})

# %%
Artist_detail[Artist_detail['artist_mb']=='James Bay']
# Out:
#                                       mbid  artist_mb artist_lastfm  \
# 1637  6a997121-0919-482b-a91b-c6fe1b55a4b9  James Bay     James Bay
#
#           country_mb  country_lastfm                            tags_mb  \
# 1637  United Kingdom  United Kingdom  alternative rock; soul; indie pop
#
#                                             tags_lastfm  listeners_lastfm  \
# 1637  folk; indie; singer-songwriter; british; seen ...          550211.0
#
#       scrobbles_lastfm  ambiguous_artist
# 1637        10381544.0             False

# %%
len(Artist_detail)
# Out:
# 1466083

# %%
#Artist_detail.artist_name.isna().sum()

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# # function to get information on top tracks, passing in the playlist URI
# # QUESTION: is there a way to return this data without having to append them in these different lists?
#
# track_names = []
# track_ids = []
# track_uris = []
# artist_names = []
# album_release_dates = []
# track_years = []
# popular_years = []
#
# def tophitsyear(url):
#     for track in sp.playlist_tracks(url)["items"]:
#         track_name = track["track"]["name"]
#         track_names.append(track_name)
#         track_id = track["track"]["id"]
#         track_ids.append(track_id)
#         track_uri = track["track"]["uri"]
#         track_uris.append(track_uri)
#         #artist_name = track["track"]["artists"] # too difficult to get
#         #artist_names.append(artist_name)
#         album_release_date = track["track"]["album"]["release_date"]
#         album_release_dates.append(album_release_date)
#         track_year = track["track"]["album"]["release_date"].split("-")[0]
#         track_years.append(track_year)
#         popular_year = YearDictionary[(url)]
#         popular_years.append(popular_year)
#         #print(popular_year)
#         #track_years.append(track_year)
#         #print(track_name, track_id, track_uri)
#         #return track_name, track_id, track_uri
#     #return track_names, track_ids, track_years, popular_year
#     #return track_name, track_id, track_uri, album_release_date, popular_year
#
# #tophitsyear(allLinks2)
# #empty_list = pd.DataFrame(empty_list)
# #print(popular_years)

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# #use list comprehension with function
# final_list1 = [tophitsyear(url) for url in allLinks]
# #final_list2 = pd.DataFrame(final_list1)
#
# #final_list2 = pd.DataFrame(final_list1)
# #final_list2.head()
# print(final_list1)
# #len(track_names)
# #print(track_names)

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# df = pd.DataFrame(list(zip(track_uris, track_ids, track_names, album_release_dates, track_years, popular_years)), columns=['track_uri', 'track_id', 'track_name', 'album_release_date', 'track_year', 'popular_year'])
# df.head()
# #df.shape

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# track_uris2 = df['track_uri']
# identifier_list = track_uris2.values.tolist()
# print(identifier_list)

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# AudioFeatures2 = [sp.audio_features(identifier)[0] for identifier in track_uris2]
# print(AudioFeatures2)

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# AudioFeatures2[1:10]

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# # THIS ONE WORKED
# df5 = pd.json_normalize(AudioFeatures2)
# print(df5)

# %% [markdown]
# ### steps below were to get all song audio features for years 2000-2021

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# # Initializing lists for basic track details
# artist_name = []
# artist_id = []
# album_name = []
# album_id = []
# track_name = []
# track_id = []
# track_pop = []
# track_year = []
# track_spotify_genre = []
# track_uri = []
#
# # Initiating lists for track audio features
# key = []
# acousticness = []
# danceability = []
# duration_ms = []
# energy = []
# instrumentalness = []
# liveness = []
# loudness = []
# mode = []
# speechiness = []
# tempo = []
# time_signature = []
# valence = []
#
# # Initializing genre
# artist_genre = []

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# # Get collection of song ids and basic track details - 50 tracks per. I had to run two years at a time to prevent it from timing out
# for genre in ['hip-hop', 'house','indie','pop','r&b','rock', 'soundtrack', 'jazz', 'classical', 'country', 'dance', 'alternative', 'movie', 'world', 'blues']:
#   for year in range(2020,2022):
#       query = "genre:" + genre + " year:" + str(year)
#       for i in range(0,1000,50):
#           track_results = sp.search(q=query, type='track', limit=50, offset=i) # change 'q=' argument for year
#           for item in track_results['tracks']['items']:
#               artist_name.append(item['album']['artists'][0]['name'])
#               artist_id.append(item['album']['artists'][0]['id'])
#               track_name.append(item['name'])
#               track_id.append(item['id'])
#               track_pop.append(item['popularity'])
#               track_year.append(year)
#               track_spotify_genre.append(genre)
#               #album_name.append(item['album']['name'])
#               #album_id.append(item['album']['id'])
#               track_uri.append(item['uri'])
#
# len(artist_name)

# %%
#dataset = pd.read_csv("/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/AllSongs 2000-2021.csv")

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# track_ids = dataset.track_id
# track_ids.head()

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# # this gets all audio features for the given track ids
# for i in range(0,len(track_ids),50):
#   track_features = sp.audio_features(track_ids[i:i+50]) # returns features of first 50 tracks
#   for j in range(0,len(track_features)): # iterate over those 50 tracks
#     if track_features[j] is None:  # if track does not have audio features from spotify
#       track_features[j] = {}
#     key.append(track_features[j].get('key', np.nan))
#     acousticness.append(track_features[j].get('acousticness', np.nan))
#     danceability.append(track_features[j].get('danceability', np.nan))
#     duration_ms.append(track_features[j].get('duration_ms', np.nan))
#     energy.append(track_features[j].get('energy', np.nan))
#     instrumentalness.append(track_features[j].get('instrumentalness', np.nan))
#     liveness.append(track_features[j].get('liveness', np.nan))
#     loudness.append(track_features[j].get('loudness', np.nan))
#     mode.append(track_features[j].get('mode', np.nan))
#     speechiness.append(track_features[j].get('speechiness', np.nan))
#     tempo.append(track_features[j].get('tempo', np.nan))
#     time_signature.append(track_features[j].get('time_signature', np.nan))
#     valence.append(track_features[j].get('valence', np.nan))

# %% [markdown]
# WORKING CODE, MARKDOWN FOR NOW
# this gets all the second artists on tracks.  I'll use this data to create a "collaboration" variable
#
#
# # get second artist on tracks
# for genre in ['hip-hop', 'house','indie','pop','r&b','rock', 'soundtrack', 'jazz', 'classical', 'country', 'dance', 'alternative', 'movie', 'world', 'blues']:
#     for year in range(2020,2023):
#           query = "genre:" + genre + " year:" + str(year)
#           for i in range(0,1000,50):
#               track_results = sp.search(q=query, type='track', limit=50, offset=i) # change 'q=' argument for year
#               for item in track_results['tracks']['items']:
#                     try:
#                         second_artist_name.append(item['album']['artists'][1]['name'])
#                         track_id.append(item['id'])
#                         track_uri.append(item['uri'])
#                     except:
#                         pass

# %% [markdown]
# ### WORKING CODE, MARKDOWN FOR NOW
# # create dataframe of audio features
# AllTracksAudio = pd.DataFrame({"track_id":track_ids,
#                    "key":key,
#                     "acousticness":acousticness,
#                     "danceability":danceability,
#                     "duration_ms":duration_ms,
#                     "energy":energy,
#                     "instrumentalness":instrumentalness,
#                     "liveness":liveness,
#                     "loudness":loudness,
#                     "mode":mode,
#                     "speechiness":speechiness,
#                     "tempo":tempo,
#                     "time_signature":time_signature,
#                     "valence":valence,
#                     })

# %% [markdown]
# from pathlib import Path
# filepath = Path('/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/AllSongsAudioFeatures.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# AllTracksAudio.to_csv(filepath)

# %% [markdown]
# ## Combining datasets
#
# At this point, I now have data collected, but disperesed among different files.
#
# - AllSongsAudioFeatures.csv: songs with all audio features from 2000-2021. contains audio features on 315,618 songs. I will use this as the primary file to merge data into.  There are about 60,000 duplicate track_ids that we want to drop
# - AllSongs.csv: high-level informational data (track_name, artist_name, track_genre, popularity) on 315,618 songs
# - AllCharts 2000-2021.csv: all of the Top 100 songs in each year from 2000-2021
# - SecondArtists.csv: second artists on tracks from 2000-2021

# %%
# load AllSongsAudioFeatures
AllSongsAudioFeatures = pd.read_csv("/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/AllSongsAudioFeatures.csv", index_col =[0])
#AllSongsAudioFeatures.drop_duplicates(subset='track_id', keep='first', inplace=True) # drop ~60,000 rows that don't have unique track_ID
AllSongsAudioFeatures.drop_duplicates(keep='first', inplace=True) # drop ~60,000 rows that don't have unique track_ID

# %%
AllSongsAudioFeatures.track_id.value_counts()
# Out:
# 3yfqSUWxFvZELEM4PmlwIR    1
# 0r3ur5jBMpjkcrqbVVvgs7    1
# 4lXBIshfa0juWxi6odtLHt    1
# 4iddUbzyhbLEqhsVcZmc7u    1
# 4OfCkjpcpqKgr9igYyOSHm    1
#                          ..
# 5yqO0ETHCWHhy1Jf4ltayp    1
# 7A5uV4KrkkOO7ZipSPCAI6    1
# 6rZwfQkFFafuyU1SDSBx6u    1
# 5elDLvpi4MB1NT02PjbgtE    1
# 0IUtfOQZrk5NTuor7XvAW0    1
# Name: track_id, Length: 255098, dtype: int64

# %%
len(AllSongsAudioFeatures)
# Out:
# 255098

# %%
#AllSongsAudioFeatures.value_counts()

# %%
# load AllSongs
AllSongs = pd.read_csv("/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/AllSongs 2000-2021.csv", index_col =[0])
AllSongs.drop_duplicates(subset='track_id', keep='first', inplace=True) # drop ~60,000 rows that don't have unique track_ID

# %%
AllSongs.shape
# Out:
# (267210, 8)

# %%
# load AllCharts
AllCharts = pd.read_csv("/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/AllCharts 2000-2021.csv", index_col =[0])
AllCharts.drop_duplicates(subset='track_id', keep='first', inplace=True) # drop second value of 96 songs that appeared in the Top 100 list in two different years

# %%
AllCharts.shape
# Out:
# (2104, 7)

# %%
AllCharts.head()
# Out:
#                               track_uri                track_id  \
# 0  spotify:track:6naxalmIoLFWR0siv8dnQQ  6naxalmIoLFWR0siv8dnQQ
# 1  spotify:track:2m1hi0nfMR9vdGC8UcrnwU  2m1hi0nfMR9vdGC8UcrnwU
# 2  spotify:track:3y4LxiYMgDl4RethdzpmNe  3y4LxiYMgDl4RethdzpmNe
# 3  spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l  0v1XpBHnsbkCn7iJ9Ucr1l
# 4  spotify:track:62bOmKYxYg7dhrC6gH9vFn  62bOmKYxYg7dhrC6gH9vFn
#
#                track_name album_release_date  track_year  popular_year Top100
# 0  Oops!...I Did It Again         2000-05-16        2000          2000      Y
# 1    All The Small Things         1999-06-01        1999          2000      Y
# 2                 Breathe         1999-11-09        1999          2000      Y
# 3            It's My Life         2000-01-01        2000          2000      Y
# 4             Bye Bye Bye         2000-03-21        2000          2000      Y

# %%
AllCharts.isna().sum()
# Out:
# track_uri             0
# track_id              0
# track_name            0
# album_release_date    0
# track_year            0
# popular_year          0
# Top100                0
# dtype: int64

# %%
# load second artists
SecondArtists = pd.read_csv("/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/SecondArtists.csv", index_col =[0])
SecondArtists.drop_duplicates(keep='first', inplace=True) #

# %%
len(SecondArtists)
# Out:
# 27352

# %%
SecondArtists.head()
# Out:
#                  track_id  second_artist
# 0  0mXMr1OVZZKYmOinBaofOp  Three 6 Mafia
# 1  74iebSWsEaHSGdCE8PKKlF  Three 6 Mafia
# 2  2q4uKm1TZ6mcNktEUfeUN8  Mr. Knightowl
# 3  23m1xslbkYGR0bL7LGyrqX  Three 6 Mafia
# 4  0hDRkyeMIQ5ZrKCeLS7EJZ  Three 6 Mafia

# %%
#NellySongs = AllSongs.loc[AllSongs.art_name == 'Nelly']
#NellySongs.track_name.value_counts()

# %% [markdown]
# NellySongs.loc[AllSongs.track_name == 'Just A Dream']

# %% [markdown]
# NellySongs.track_id.value_counts()

# %% [markdown]
# AllSongs.track_name.value_counts()

# %% [markdown]
# index_names = AllSongs[ (AllSongs['track_name'] == AllSongs['track_name']) & (AllSongs['art_name'] == AllSongs['art_name'])].index

# %% [markdown]
# len(index_names)

# %% [markdown]
# AllSongs.drop(index_names, inplace = True)

# %% [markdown]
# len(AllSongs)

# %% [markdown]
# AllSongs.track_name.value_counts()

# %% [markdown]
# AllSongs.shape

# %% [markdown]
# AllSongs.head(20)

# %%
# use track_id to merge data

# %%
# combine AllSongsAudioFeatures and AllSongs

# %% [markdown]
# AllSongs.head()

# %% [markdown]
# NellySongs = AllSongs.loc[AllSongs.art_name == 'Nelly']
# RideWitMe = NellySongs.loc[NellySongs.track_name == 'Ride Wit Me']
# print(RideWitMe)

# %% [markdown]
# RideWitMe = RideWitMe.drop_duplicates(subset='track_id', keep='first', inplace=True)

# %% [markdown]
# print(RideWitMe)

# %% [markdown]
# AllSongsAudioFeatures.head()

# %% [markdown]
# len(AllSongsAudioFeatures)

# %% [markdown]
# AllSongsAudioFeatures.track_id.value_counts()

# %% [markdown]
# ### Begin merges

# %% [markdown]
# df1 = pd.merge(AllSongs, AllSongsAudioFeatures, on='track_id', how='outer')

# %% [markdown]
# df1.shape

# %%
#df8 = pd.merge(AllCharts, AllSongs, on='track_id', how='left')

# %%
#df8[df8['art_name'].isna()]

# %%
df1 = pd.merge(AllSongs, AllCharts, on='track_id', how='outer')

# %%
#df1.isna().sum()

# %%
#df1 = pd.merge(AllSongsAudioFeatures, AllSongs[('track_name', 'track_spotify_genre', 'art_name', 'track_pop')], left_index=True, right_index=True, on='track_id', how='outer')

# %%
#dfleft = pd.merge(AllSongsAudioFeatures, AllSongs, on='track_id', how='left')

# %%
#dfleft.shape

# %%
#dfleft.isna().sum()

# %%
df1.track_id.value_counts()
# Out:
# 3yfqSUWxFvZELEM4PmlwIR    1
# 40tuNJI1oMnRmg8esXBNBC    1
# 6BzJljXLttOtiNUj2IsvTW    1
# 33tCXFaLiKm6jdxWsxBVkL    1
# 1qh5qGydOubagDlGCt6vPI    1
#                          ..
# 6zRebcwRNu8DIOC1AdF3uV    1
# 7p3NEgjUP1WKhuHsU1S5Mx    1
# 15agvGOY5DQgZeWkHAvQDt    1
# 0iciBMlOWGrvWtGHw3uxf3    1
# 0WSEq9Ko4kFPt8yo3ICd6T    1
# Name: track_id, Length: 267411, dtype: int64

# %%
df1.shape
# Out:
# (267411, 14)

# %%
df1.head(25)
# Out:
#                   track_id                                       track_name_x  \
# 0   3yfqSUWxFvZELEM4PmlwIR                                The Real Slim Shady
# 1   0I3q5fE6wg7LIfHGngUTnV                                        Ms. Jackson
# 2   3UmaczJpikHgJFyBTAJVoz                                               Stan
# 3   3Gf5nttwcX9aaSQXRWidEZ                                        Ride Wit Me
# 4   6glsMWIMIxQ4BedzLqGVi4                                 So Fresh, So Clean
# 5   23wfXwnsPZYe5A1xXRHb3J                                       The Way I Am
# 6   3wMUvT6eIw2L5cZFG1yH9j                         Country Grammar (Hot Shit)
# 7   5eGEc27nnhtmcOh6RC890a                                           Kill You
# 8   7lgvU7WnwcNZ8dbGUz8yhP                                    Bitch Please II
# 9   4LwOrnuxJwR7C5Sw4liY4Z             What's Your Fantasy (Featuring Shawna)
# 10  7pv80uUHfocFqfTytu1MVi                                    Didn't Cha Know
# 11  0OvwzS8FX73Bw7ykMRmffU                                       Put It On Me
# 12  3WibbMr6canxRJXhNtAvLU                        B.O.B. - Bombs Over Baghdad
# 13  5H3B1WtZYGmyOYOXgQltKU                                Under The Influence
# 14  5YBVDvTSSSiqv7KZDeUlXA                                  Renegades Of Funk
# 15  4bUfMNNmiCmPXVyWzIfKeZ                                               E.I.
# 16  2EduiM2UNwjCC7PsLxnOCH  Sippin On Some Syrup (feat. UGK (Underground K...
# 17  71u5SjnkSQgzIt1UzHchbi                                              Whoa!
# 18  0mXMr1OVZZKYmOinBaofOp                 Slob On My Nob (feat. Project Pat)
# 19  0s46SltT4On0Z6kglK1I5c                 I Just Wanna Love U (Give It 2 Me)
# 20  3xVtc7PB4V3AqAfq4Iahli                                           I'm Back
# 21  18ohWhzbMCynq5QJ68ifkW                                           Criminal
# 22  1CeizRCGEYPWooEeVfmyFL                                        A Long Walk
# 23  7flXreohxgJdOnh6Kc4bx0                    Deadly Combination (feat. 2Pac)
# 24  4NTn0Yo8hTGW5tbBANBzfh                                      You Can Do It
#
#     track_year_x track_spotify_genre                  art_name  \
# 0         2000.0             hip-hop                    Eminem
# 1         2000.0             hip-hop                   Outkast
# 2         2000.0             hip-hop                    Eminem
# 3         2000.0             hip-hop                     Nelly
# 4         2000.0             hip-hop                   Outkast
# 5         2000.0             hip-hop                    Eminem
# 6         2000.0             hip-hop                     Nelly
# 7         2000.0             hip-hop                    Eminem
# 8         2000.0             hip-hop                    Eminem
# 9         2000.0             hip-hop                  Ludacris
# 10        2000.0             hip-hop               Erykah Badu
# 11        2000.0             hip-hop                   Ja Rule
# 12        2000.0             hip-hop                   Outkast
# 13        2000.0             hip-hop                    Eminem
# 14        2000.0             hip-hop  Rage Against The Machine
# 15        2000.0             hip-hop                     Nelly
# 16        2000.0             hip-hop             Three 6 Mafia
# 17        2000.0             hip-hop                 Black Rob
# 18        2000.0             hip-hop     Tear Da Club Up Thugs
# 19        2000.0             hip-hop                     JAY-Z
# 20        2000.0             hip-hop                    Eminem
# 21        2000.0             hip-hop                    Eminem
# 22        2000.0             hip-hop                Jill Scott
# 23        2000.0             hip-hop                     Big L
# 24        2000.0             hip-hop                  Ice Cube
#
#                     art_id                           track_uri_x  track_pop  \
# 0   7dGJo4pcD2V6oG8kP0tJRR  spotify:track:3yfqSUWxFvZELEM4PmlwIR       88.0
# 1   1G9G7WwrXka3Z1r7aIDjI7  spotify:track:0I3q5fE6wg7LIfHGngUTnV       82.0
# 2   7dGJo4pcD2V6oG8kP0tJRR  spotify:track:3UmaczJpikHgJFyBTAJVoz       85.0
# 3   2gBjLmx6zQnFGQJCAQpRgw  spotify:track:3Gf5nttwcX9aaSQXRWidEZ       75.0
# 4   1G9G7WwrXka3Z1r7aIDjI7  spotify:track:6glsMWIMIxQ4BedzLqGVi4       72.0
# 5   7dGJo4pcD2V6oG8kP0tJRR  spotify:track:23wfXwnsPZYe5A1xXRHb3J       75.0
# 6   2gBjLmx6zQnFGQJCAQpRgw  spotify:track:3wMUvT6eIw2L5cZFG1yH9j       69.0
# 7   7dGJo4pcD2V6oG8kP0tJRR  spotify:track:5eGEc27nnhtmcOh6RC890a       70.0
# 8   7dGJo4pcD2V6oG8kP0tJRR  spotify:track:7lgvU7WnwcNZ8dbGUz8yhP       72.0
# 9   3ipn9JLAPI5GUEo4y4jcoi  spotify:track:4LwOrnuxJwR7C5Sw4liY4Z       63.0
# 10  7IfculRW2WXyzNQ8djX8WX  spotify:track:7pv80uUHfocFqfTytu1MVi       67.0
# 11  1J2VVASYAamtQ3Bt8wGgA6  spotify:track:0OvwzS8FX73Bw7ykMRmffU       64.0
# 12  1G9G7WwrXka3Z1r7aIDjI7  spotify:track:3WibbMr6canxRJXhNtAvLU       62.0
# 13  7dGJo4pcD2V6oG8kP0tJRR  spotify:track:5H3B1WtZYGmyOYOXgQltKU       68.0
# 14  2d0hyoQ5ynDBnkvAbJKORj  spotify:track:5YBVDvTSSSiqv7KZDeUlXA       66.0
# 15  2gBjLmx6zQnFGQJCAQpRgw  spotify:track:4bUfMNNmiCmPXVyWzIfKeZ       61.0
# 16  26s8LSolLfCIY88ysQbIuT  spotify:track:2EduiM2UNwjCC7PsLxnOCH       59.0
# 17  1QPZhx0asYTBxD5RDqfU49  spotify:track:71u5SjnkSQgzIt1UzHchbi       59.0
# 18  6EXX0GpVsILp9TGCfu7AVG  spotify:track:0mXMr1OVZZKYmOinBaofOp       58.0
# 19  3nFkdlSjzX9mRTtwJOzDYB  spotify:track:0s46SltT4On0Z6kglK1I5c       60.0
# 20  7dGJo4pcD2V6oG8kP0tJRR  spotify:track:3xVtc7PB4V3AqAfq4Iahli       62.0
# 21  7dGJo4pcD2V6oG8kP0tJRR  spotify:track:18ohWhzbMCynq5QJ68ifkW       61.0
# 22  6AVLthptCPhfrxlHadOBJD  spotify:track:1CeizRCGEYPWooEeVfmyFL       56.0
# 23  30fiiwr2EeZp1tAhzYCmyM  spotify:track:7flXreohxgJdOnh6Kc4bx0       63.0
# 24  3Mcii5XWf6E0lrY3Uky4cA  spotify:track:4NTn0Yo8hTGW5tbBANBzfh       62.0
#
#                              track_uri_y                        track_name_y  \
# 0   spotify:track:3yfqSUWxFvZELEM4PmlwIR                 The Real Slim Shady
# 1   spotify:track:0I3q5fE6wg7LIfHGngUTnV                         Ms. Jackson
# 2   spotify:track:3UmaczJpikHgJFyBTAJVoz                                Stan
# 3   spotify:track:3Gf5nttwcX9aaSQXRWidEZ                         Ride Wit Me
# 4                                    NaN                                 NaN
# 5                                    NaN                                 NaN
# 6   spotify:track:3wMUvT6eIw2L5cZFG1yH9j          Country Grammar (Hot Shit)
# 7                                    NaN                                 NaN
# 8                                    NaN                                 NaN
# 9                                    NaN                                 NaN
# 10                                   NaN                                 NaN
# 11  spotify:track:0OvwzS8FX73Bw7ykMRmffU                        Put It On Me
# 12                                   NaN                                 NaN
# 13                                   NaN                                 NaN
# 14                                   NaN                                 NaN
# 15                                   NaN                                 NaN
# 16                                   NaN                                 NaN
# 17                                   NaN                                 NaN
# 18                                   NaN                                 NaN
# 19  spotify:track:0s46SltT4On0Z6kglK1I5c  I Just Wanna Love U (Give It 2 Me)
# 20                                   NaN                                 NaN
# 21                                   NaN                                 NaN
# 22                                   NaN                                 NaN
# 23                                   NaN                                 NaN
# 24                                   NaN                                 NaN
#
#    album_release_date  track_year_y  popular_year Top100
# 0          2000-05-23        2000.0        2000.0      Y
# 1          2000-10-31        2000.0        2001.0      Y
# 2          2000-05-23        2000.0        2001.0      Y
# 3          2000-06-27        2000.0        2001.0      Y
# 4                 NaN           NaN           NaN    NaN
# 5                 NaN           NaN           NaN    NaN
# 6          2000-06-27        2000.0        2000.0      Y
# 7                 NaN           NaN           NaN    NaN
# 8                 NaN           NaN           NaN    NaN
# 9                 NaN           NaN           NaN    NaN
# 10                NaN           NaN           NaN    NaN
# 11         2000-01-01        2000.0        2001.0      Y
# 12                NaN           NaN           NaN    NaN
# 13                NaN           NaN           NaN    NaN
# 14                NaN           NaN           NaN    NaN
# 15                NaN           NaN           NaN    NaN
# 16                NaN           NaN           NaN    NaN
# 17                NaN           NaN           NaN    NaN
# 18                NaN           NaN           NaN    NaN
# 19         2000-10-31        2000.0        2000.0      Y
# 20                NaN           NaN           NaN    NaN
# 21                NaN           NaN           NaN    NaN
# 22                NaN           NaN           NaN    NaN
# 23                NaN           NaN           NaN    NaN
# 24                NaN           NaN           NaN    NaN

# %%
df1.isnull().sum()
# Out:
# track_id                    0
# track_name_x              201
# track_year_x              201
# track_spotify_genre       201
# art_name                  203
# art_id                    201
# track_uri_x               201
# track_pop                 201
# track_uri_y            265307
# track_name_y           265307
# album_release_date     265307
# track_year_y           265307
# popular_year           265307
# Top100                 265307
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267411 entries, 0 to 267410
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   track_id             267411 non-null  object
#  1   track_name_x         267210 non-null  object
#  2   track_year_x         267210 non-null  float64
#  3   track_spotify_genre  267210 non-null  object
#  4   art_name             267208 non-null  object
#  5   art_id               267210 non-null  object
#  6   track_uri_x          267210 non-null  object
#  7   track_pop            267210 non-null  float64
#  8   track_uri_y          2104 non-null    object
#  9   track_name_y         2104 non-null    object
#  10  album_release_date   2104 non-null    object
#  11  track_year_y         2104 non-null    float64
#  12  popular_year         2104 non-null    float64
#  13  Top100               2104 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 30.6+ MB

# %%
df1.nunique()
# Out:
# track_id               267411
# track_name_x           196942
# track_year_x               23
# track_spotify_genre        15
# art_name                23267
# art_id                  23298
# track_uri_x            267210
# track_pop                  95
# track_uri_y              2104
# track_name_y             2037
# album_release_date        965
# track_year_y               25
# popular_year               22
# Top100                      1
# dtype: int64

# %%
# there are a number of songs without critical information.  drop all values that don't have an art_name
df1 = df1[df1['art_name'].notna()]
# note this leaves us with 1,903 observations that were Top100

# %%
df2 = pd.merge(df1, AllSongsAudioFeatures, on='track_id', how='left')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267208 entries, 0 to 267207
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   track_id             267208 non-null  object
#  1   track_name_x         267208 non-null  object
#  2   track_year_x         267208 non-null  float64
#  3   track_spotify_genre  267208 non-null  object
#  4   art_name             267208 non-null  object
#  5   art_id               267208 non-null  object
#  6   track_uri_x          267208 non-null  object
#  7   track_pop            267208 non-null  float64
#  8   track_uri_y          1903 non-null    object
#  9   track_name_y         1903 non-null    object
#  10  album_release_date   1903 non-null    object
#  11  track_year_y         1903 non-null    float64
#  12  popular_year         1903 non-null    float64
#  13  Top100               1903 non-null    object
#  14  key                  255096 non-null  float64
#  15  acousticness         255096 non-null  float64
#  16  danceability         255096 non-null  float64
#  17  duration_ms          255096 non-null  float64
#  18  energy               255096 non-null  float64
#  19  instrumentalness     255096 non-null  float64
#  20  liveness             255096 non-null  float64
#  21  loudness             255096 non-null  float64
#  22  mode                 255096 non-null  float64
#  23  speechiness          255096 non-null  float64
#  24  tempo                255096 non-null  float64
#  25  time_signature       255096 non-null  float64
#  26  valence              255096 non-null  float64
# dtypes: float64(17), object(10)
# memory usage: 57.1+ MB

# %%
df2.isnull().sum()
# Out:
# track_id                    0
# track_name_x                0
# track_year_x                0
# track_spotify_genre         0
# art_name                    0
# art_id                      0
# track_uri_x                 0
# track_pop                   0
# track_uri_y            265305
# track_name_y           265305
# album_release_date     265305
# track_year_y           265305
# popular_year           265305
# Top100                 265305
# key                     12112
# acousticness            12112
# danceability            12112
# duration_ms             12112
# energy                  12112
# instrumentalness        12112
# liveness                12112
# loudness                12112
# mode                    12112
# speechiness             12112
# tempo                   12112
# time_signature          12112
# valence                 12112
# dtype: int64

# %%
# there are a number of songs without audio information.  drop all values that don't have acousticness (could have used any variable)
df2 = df2[df2['acousticness'].notna()]
# note this leaves us with 1,863 observations that were Top100

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255096 entries, 0 to 255095
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   track_id             255096 non-null  object
#  1   track_name_x         255096 non-null  object
#  2   track_year_x         255096 non-null  float64
#  3   track_spotify_genre  255096 non-null  object
#  4   art_name             255096 non-null  object
#  5   art_id               255096 non-null  object
#  6   track_uri_x          255096 non-null  object
#  7   track_pop            255096 non-null  float64
#  8   track_uri_y          1863 non-null    object
#  9   track_name_y         1863 non-null    object
#  10  album_release_date   1863 non-null    object
#  11  track_year_y         1863 non-null    float64
#  12  popular_year         1863 non-null    float64
#  13  Top100               1863 non-null    object
#  14  key                  255096 non-null  float64
#  15  acousticness         255096 non-null  float64
#  16  danceability         255096 non-null  float64
#  17  duration_ms          255096 non-null  float64
#  18  energy               255096 non-null  float64
#  19  instrumentalness     255096 non-null  float64
#  20  liveness             255096 non-null  float64
#  21  loudness             255096 non-null  float64
#  22  mode                 255096 non-null  float64
#  23  speechiness          255096 non-null  float64
#  24  tempo                255096 non-null  float64
#  25  time_signature       255096 non-null  float64
#  26  valence              255096 non-null  float64
# dtypes: float64(17), object(10)
# memory usage: 54.5+ MB

# %%
df2.nunique()
# Out:
# track_id               255096
# track_name_x           188539
# track_year_x               22
# track_spotify_genre        15
# art_name                22772
# art_id                  22802
# track_uri_x            255096
# track_pop                  95
# track_uri_y              1863
# track_name_y             1812
# album_release_date        867
# track_year_y               22
# popular_year               22
# Top100                      1
# key                        12
# acousticness             5032
# danceability             1314
# duration_ms             84943
# energy                   2729
# instrumentalness         5401
# liveness                 1753
# loudness                30094
# mode                        2
# speechiness              1545
# tempo                   89703
# time_signature              5
# valence                  1710
# dtype: int64

# %%
df2.Top100.value_counts()
# Out:
# Y    1863
# Name: Top100, dtype: int64

# %%
df3 = pd.merge(df2, SecondArtists, on='track_id', how='left')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255096 entries, 0 to 255095
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   track_id             255096 non-null  object
#  1   track_name_x         255096 non-null  object
#  2   track_year_x         255096 non-null  float64
#  3   track_spotify_genre  255096 non-null  object
#  4   art_name             255096 non-null  object
#  5   art_id               255096 non-null  object
#  6   track_uri_x          255096 non-null  object
#  7   track_pop            255096 non-null  float64
#  8   track_uri_y          1863 non-null    object
#  9   track_name_y         1863 non-null    object
#  10  album_release_date   1863 non-null    object
#  11  track_year_y         1863 non-null    float64
#  12  popular_year         1863 non-null    float64
#  13  Top100               1863 non-null    object
#  14  key                  255096 non-null  float64
#  15  acousticness         255096 non-null  float64
#  16  danceability         255096 non-null  float64
#  17  duration_ms          255096 non-null  float64
#  18  energy               255096 non-null  float64
#  19  instrumentalness     255096 non-null  float64
#  20  liveness             255096 non-null  float64
#  21  loudness             255096 non-null  float64
#  22  mode                 255096 non-null  float64
#  23  speechiness          255096 non-null  float64
#  24  tempo                255096 non-null  float64
#  25  time_signature       255096 non-null  float64
#  26  valence              255096 non-null  float64
#  27  second_artist        24125 non-null   object
# dtypes: float64(17), object(11)
# memory usage: 56.4+ MB

# %%
df3.Top100.value_counts()
# Out:
# Y    1863
# Name: Top100, dtype: int64

# %%
df3.nunique()
# Out:
# track_id               255096
# track_name_x           188539
# track_year_x               22
# track_spotify_genre        15
# art_name                22772
# art_id                  22802
# track_uri_x            255096
# track_pop                  95
# track_uri_y              1863
# track_name_y             1812
# album_release_date        867
# track_year_y               22
# popular_year               22
# Top100                      1
# key                        12
# acousticness             5032
# danceability             1314
# duration_ms             84943
# energy                   2729
# instrumentalness         5401
# liveness                 1753
# loudness                30094
# mode                        2
# speechiness              1545
# tempo                   89703
# time_signature              5
# valence                  1710
# second_artist            6883
# dtype: int64

# %%
df3.head()
# Out:
#                  track_id         track_name_x  track_year_x  \
# 0  3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady        2000.0
# 1  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson        2000.0
# 2  3UmaczJpikHgJFyBTAJVoz                 Stan        2000.0
# 3  3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me        2000.0
# 4  6glsMWIMIxQ4BedzLqGVi4   So Fresh, So Clean        2000.0
#
#   track_spotify_genre art_name                  art_id  \
# 0             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 1             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
# 2             hip-hop   Eminem  7dGJo4pcD2V6oG8kP0tJRR
# 3             hip-hop    Nelly  2gBjLmx6zQnFGQJCAQpRgw
# 4             hip-hop  Outkast  1G9G7WwrXka3Z1r7aIDjI7
#
#                             track_uri_x  track_pop  \
# 0  spotify:track:3yfqSUWxFvZELEM4PmlwIR       88.0
# 1  spotify:track:0I3q5fE6wg7LIfHGngUTnV       82.0
# 2  spotify:track:3UmaczJpikHgJFyBTAJVoz       85.0
# 3  spotify:track:3Gf5nttwcX9aaSQXRWidEZ       75.0
# 4  spotify:track:6glsMWIMIxQ4BedzLqGVi4       72.0
#
#                             track_uri_y         track_name_y  ... energy  \
# 0  spotify:track:3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady  ...  0.661
# 1  spotify:track:0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson  ...  0.806
# 2  spotify:track:3UmaczJpikHgJFyBTAJVoz                 Stan  ...  0.768
# 3  spotify:track:3Gf5nttwcX9aaSQXRWidEZ          Ride Wit Me  ...  0.700
# 4                                   NaN                  NaN  ...  0.640
#
#    instrumentalness  liveness loudness  mode  speechiness    tempo  \
# 0          0.000000    0.0454   -4.244   0.0       0.0572  104.504
# 1          0.000000    0.0771   -5.946   0.0       0.2690   94.948
# 2          0.000002    0.5180   -4.325   0.0       0.2380   80.063
# 3          0.000002    0.2440   -6.490   1.0       0.0478  101.875
# 4          0.000000    0.0990   -7.905   0.0       0.3320  166.028
#
#    time_signature  valence  second_artist
# 0             4.0    0.760            NaN
# 1             4.0    0.613            NaN
# 2             4.0    0.507            NaN
# 3             4.0    0.722            NaN
# 4             3.0    0.915            NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## With all of the datasets combined, we need to do some cleaning.  I noticed earlier that there are duplicate track_ids, track_uri, genres per song

# %%
df3.isna().sum()
# Out:
# track_id                    0
# track_name_x                0
# track_year_x                0
# track_spotify_genre         0
# art_name                    0
# art_id                      0
# track_uri_x                 0
# track_pop                   0
# track_uri_y            253233
# track_name_y           253233
# album_release_date     253233
# track_year_y           253233
# popular_year           253233
# Top100                 253233
# key                         0
# acousticness                0
# danceability                0
# duration_ms                 0
# energy                      0
# instrumentalness            0
# liveness                    0
# loudness                    0
# mode                        0
# speechiness                 0
# tempo                       0
# time_signature              0
# valence                     0
# second_artist          230971
# dtype: int64

# %%
#drop some columns that we don't need
df4 = df3.drop(['track_year_y', 'track_year_x', 'track_uri_x', 'track_uri_y', 'album_release_date', 'track_name_y', 'art_id'], axis=1)

# %%
df4 = df4.rename(columns = {'track_pop':'track_popularity', 'track_name_x':'track_name', 'track_spotify_genre':'track_genre', 'mode':'modality', 'art_name':'artist_name'})

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255096 entries, 0 to 255095
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          255096 non-null  object
#  1   track_name        255096 non-null  object
#  2   track_genre       255096 non-null  object
#  3   artist_name       255096 non-null  object
#  4   track_popularity  255096 non-null  float64
#  5   popular_year      1863 non-null    float64
#  6   Top100            1863 non-null    object
#  7   key               255096 non-null  float64
#  8   acousticness      255096 non-null  float64
#  9   danceability      255096 non-null  float64
#  10  duration_ms       255096 non-null  float64
#  11  energy            255096 non-null  float64
#  12  instrumentalness  255096 non-null  float64
#  13  liveness          255096 non-null  float64
#  14  loudness          255096 non-null  float64
#  15  modality          255096 non-null  float64
#  16  speechiness       255096 non-null  float64
#  17  tempo             255096 non-null  float64
#  18  time_signature    255096 non-null  float64
#  19  valence           255096 non-null  float64
#  20  second_artist     24125 non-null   object
# dtypes: float64(15), object(6)
# memory usage: 42.8+ MB

# %%
df4.isna().sum()
# Out:
# track_id                 0
# track_name               0
# track_genre              0
# artist_name              0
# track_popularity         0
# popular_year        253233
# Top100              253233
# key                      0
# acousticness             0
# danceability             0
# duration_ms              0
# energy                   0
# instrumentalness         0
# liveness                 0
# loudness                 0
# modality                 0
# speechiness              0
# tempo                    0
# time_signature           0
# valence                  0
# second_artist       230971
# dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255096 entries, 0 to 255095
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          255096 non-null  object
#  1   track_name        255096 non-null  object
#  2   track_genre       255096 non-null  object
#  3   artist_name       255096 non-null  object
#  4   track_popularity  255096 non-null  float64
#  5   popular_year      1863 non-null    float64
#  6   Top100            1863 non-null    object
#  7   key               255096 non-null  float64
#  8   acousticness      255096 non-null  float64
#  9   danceability      255096 non-null  float64
#  10  duration_ms       255096 non-null  float64
#  11  energy            255096 non-null  float64
#  12  instrumentalness  255096 non-null  float64
#  13  liveness          255096 non-null  float64
#  14  loudness          255096 non-null  float64
#  15  modality          255096 non-null  float64
#  16  speechiness       255096 non-null  float64
#  17  tempo             255096 non-null  float64
#  18  time_signature    255096 non-null  float64
#  19  valence           255096 non-null  float64
#  20  second_artist     24125 non-null   object
# dtypes: float64(15), object(6)
# memory usage: 42.8+ MB

# %%
df4.nunique()
# Out:
# track_id            255096
# track_name          188539
# track_genre             15
# artist_name          22772
# track_popularity        95
# popular_year            22
# Top100                   1
# key                     12
# acousticness          5032
# danceability          1314
# duration_ms          84943
# energy                2729
# instrumentalness      5401
# liveness              1753
# loudness             30094
# modality                 2
# speechiness           1545
# tempo                89703
# time_signature           5
# valence               1710
# second_artist         6883
# dtype: int64

# %%
df5 = df4.merge(Artist_detail[['country_mb', 'artist_mb']], how = 'left',
                left_on = 'artist_name', right_on = 'artist_mb').drop(columns = ['artist_mb'])

#df5 = pd.merge(df4, Artist_detail['country_mb'], how='left', on='artist_name')

# %%
#df5 = pd.merge(df4, Artist_detail[['artist_name','country_mb']], how='left', on='artist_name')

# %%
#355119

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 355119 entries, 0 to 355118
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          355119 non-null  object
#  1   track_name        355119 non-null  object
#  2   track_genre       355119 non-null  object
#  3   artist_name       355119 non-null  object
#  4   track_popularity  355119 non-null  float64
#  5   popular_year      3148 non-null    float64
#  6   Top100            3148 non-null    object
#  7   key               355119 non-null  float64
#  8   acousticness      355119 non-null  float64
#  9   danceability      355119 non-null  float64
#  10  duration_ms       355119 non-null  float64
#  11  energy            355119 non-null  float64
#  12  instrumentalness  355119 non-null  float64
#  13  liveness          355119 non-null  float64
#  14  loudness          355119 non-null  float64
#  15  modality          355119 non-null  float64
#  16  speechiness       355119 non-null  float64
#  17  tempo             355119 non-null  float64
#  18  time_signature    355119 non-null  float64
#  19  valence           355119 non-null  float64
#  20  second_artist     32501 non-null   object
#  21  country_mb        243328 non-null  object
# dtypes: float64(15), object(7)
# memory usage: 62.3+ MB

# %%
df5.nunique()
# Out:
# track_id            255096
# track_name          188539
# track_genre             15
# artist_name          22772
# track_popularity        95
# popular_year            22
# Top100                   1
# key                     12
# acousticness          5032
# danceability          1314
# duration_ms          84943
# energy                2729
# instrumentalness      5401
# liveness              1753
# loudness             30094
# modality                 2
# speechiness           1545
# tempo                89703
# time_signature           5
# valence               1710
# second_artist         6883
# country_mb             145
# dtype: int64

# %%
df5.isna().sum()
# Out:
# track_id                 0
# track_name               0
# track_genre              0
# artist_name              0
# track_popularity         0
# popular_year        351971
# Top100              351971
# key                      0
# acousticness             0
# danceability             0
# duration_ms              0
# energy                   0
# instrumentalness         0
# liveness                 0
# loudness                 0
# modality                 0
# speechiness              0
# tempo                    0
# time_signature           0
# valence                  0
# second_artist       322618
# country_mb          111791
# dtype: int64

# %% [markdown]
# second_artist       322618
# country_mb          111791

# %%
#subset = df5[df5['country_mb'] ]

# %%
display(df5.loc[(df5['country_mb'].notnull()) & (df5['artist_name'] == 'Drake')])
# Out:
#                       track_id          track_name track_genre artist_name  \
# 137228  3QLjDkgLh9AOEHlhQtDuhs     Best I Ever Had     hip-hop       Drake
# 137229  3QLjDkgLh9AOEHlhQtDuhs     Best I Ever Had     hip-hop       Drake
# 137230  3QLjDkgLh9AOEHlhQtDuhs     Best I Ever Had     hip-hop       Drake
# 137255  5aooThgj87ID0vgiyvcjPM         I'm Goin In     hip-hop       Drake
# 137256  5aooThgj87ID0vgiyvcjPM         I'm Goin In     hip-hop       Drake
# ...                        ...                 ...         ...         ...
# 334284  1PDP7mLiAMwhfmgIwzhOm2  Yebba’s Heartbreak         pop       Drake
# 334285  1PDP7mLiAMwhfmgIwzhOm2  Yebba’s Heartbreak         pop       Drake
# 334301  2HSmyk2qMN8WQjuGhaQgCk    Champagne Poetry         pop       Drake
# 334302  2HSmyk2qMN8WQjuGhaQgCk    Champagne Poetry         pop       Drake
# 334303  2HSmyk2qMN8WQjuGhaQgCk    Champagne Poetry         pop       Drake
#
#         track_popularity  popular_year Top100  key  acousticness  \
# 137228              77.0        2009.0      Y  1.0        0.1900
# 137229              77.0        2009.0      Y  1.0        0.1900
# 137230              77.0        2009.0      Y  1.0        0.1900
# 137255              63.0           NaN    NaN  1.0        0.0389
# 137256              63.0           NaN    NaN  1.0        0.0389
# ...                  ...           ...    ...  ...           ...
# 334284              78.0           NaN    NaN  8.0        0.9670
# 334285              78.0           NaN    NaN  8.0        0.9670
# 334301              76.0           NaN    NaN  6.0        0.7580
# 334302              76.0           NaN    NaN  6.0        0.7580
# 334303              76.0           NaN    NaN  6.0        0.7580
#
#         danceability  ...  instrumentalness  liveness  loudness  modality  \
# 137228         0.395  ...            0.0000     0.134    -2.176       1.0
# 137229         0.395  ...            0.0000     0.134    -2.176       1.0
# 137230         0.395  ...            0.0000     0.134    -2.176       1.0
# 137255         0.662  ...            0.0000     0.103    -8.455       1.0
# 137256         0.662  ...            0.0000     0.103    -8.455       1.0
# ...              ...  ...               ...       ...       ...       ...
# 334284         0.476  ...            0.0381     0.109   -11.665       0.0
# 334285         0.476  ...            0.0381     0.109   -11.665       0.0
# 334301         0.423  ...            0.0000     0.246    -7.012       0.0
# 334302         0.423  ...            0.0000     0.246    -7.012       0.0
# 334303         0.423  ...            0.0000     0.246    -7.012       0.0
#
#         speechiness    tempo  time_signature  valence  second_artist  \
# 137228       0.3750  162.361             4.0   0.5580            NaN
# 137229       0.3750  162.361             4.0   0.5580            NaN
# 137230       0.3750  162.361             4.0   0.5580            NaN
# 137255       0.3770  170.031             4.0   0.5660            NaN
# 137256       0.3770  170.031             4.0   0.5660            NaN
# ...             ...      ...             ...      ...            ...
# 334284       0.0407  119.614             4.0   0.0908            NaN
# 334285       0.0407  119.614             4.0   0.0908            NaN
# 334301       0.3260   86.743             4.0   0.4960            NaN
# 334302       0.3260   86.743             4.0   0.4960            NaN
# 334303       0.3260   86.743             4.0   0.4960            NaN
#
#         country_mb
# 137228      Canada
# 137229       Chile
# 137230      Poland
# 137255      Canada
# 137256       Chile
# ...            ...
# 334284       Chile
# 334285      Poland
# 334301      Canada
# 334302       Chile
# 334303      Poland
#
# [888 rows x 22 columns]

# %%
df5[df5.country_mb.notnull()]
# Out:
#                       track_id                             track_name  \
# 0       3yfqSUWxFvZELEM4PmlwIR                    The Real Slim Shady
# 2       3UmaczJpikHgJFyBTAJVoz                                   Stan
# 3       3Gf5nttwcX9aaSQXRWidEZ                            Ride Wit Me
# 8       23wfXwnsPZYe5A1xXRHb3J                           The Way I Am
# 9       3wMUvT6eIw2L5cZFG1yH9j             Country Grammar (Hot Shit)
# ...                        ...                                    ...
# 355114  5kJKOO7eYN9PqHi2An3lRj                        So-Called Lover
# 355115  2ByPBH09DXKl9KiWMQ3w7u                             Look Alive
# 355116  1bAAzNDtN9VMcYrxCbOUsw             Love is Gonna Come at Last
# 355117  5R61oQZBCkNZGSCnnIj7yo                             You Wonder
# 355118  0IUtfOQZrk5NTuor7XvAW0  Can't You See What You're Doing To Me
#
#        track_genre         artist_name  track_popularity  popular_year Top100  \
# 0          hip-hop              Eminem              88.0        2000.0      Y
# 2          hip-hop              Eminem              85.0        2001.0      Y
# 3          hip-hop               Nelly              75.0        2001.0      Y
# 8          hip-hop              Eminem              75.0           NaN    NaN
# 9          hip-hop               Nelly              69.0        2000.0      Y
# ...            ...                 ...               ...           ...    ...
# 355114       blues       Samantha Fish              21.0           NaN    NaN
# 355115       blues   Black Pistol Fire              23.0           NaN    NaN
# 355116       blues           Badfinger              23.0           NaN    NaN
# 355117       blues        Dinosaur Jr.              23.0           NaN    NaN
# 355118       blues  Joanne Shaw Taylor              24.0           NaN    NaN
#
#         key  acousticness  danceability  ...  instrumentalness  liveness  \
# 0       5.0       0.03020         0.949  ...          0.000000    0.0454
# 2       6.0       0.03710         0.780  ...          0.000002    0.5180
# 3       7.0       0.06160         0.850  ...          0.000002    0.2440
# 8       4.0       0.14400         0.785  ...          0.000000    0.3090
# 9       2.0       0.00689         0.865  ...          0.000000    0.1420
# ...     ...           ...           ...  ...               ...       ...
# 355114  7.0       0.00582         0.429  ...          0.000000    0.3310
# 355115  9.0       0.02180         0.677  ...          0.004210    0.2690
# 355116  2.0       0.04750         0.555  ...          0.000389    0.1980
# 355117  4.0       0.07780         0.586  ...          0.022800    0.0863
# 355118  6.0       0.22100         0.472  ...          0.000240    0.4860
#
#         loudness  modality  speechiness    tempo  time_signature  valence  \
# 0         -4.244       0.0       0.0572  104.504             4.0    0.760
# 2         -4.325       0.0       0.2380   80.063             4.0    0.507
# 3         -6.490       1.0       0.0478  101.875             4.0    0.722
# 8         -2.692       0.0       0.2650   87.248             4.0    0.315
# 9         -6.822       1.0       0.1080  162.831             4.0    0.565
# ...          ...       ...          ...      ...             ...      ...
# 355114    -0.963       1.0       0.0540  170.074             4.0    0.704
# 355115    -6.038       0.0       0.0246   94.013             4.0    0.325
# 355116    -6.834       1.0       0.0301  111.037             4.0    0.745
# 355117    -8.509       0.0       0.0268  114.498             4.0    0.509
# 355118    -2.763       0.0       0.1250  142.430             3.0    0.560
#
#         second_artist      country_mb
# 0                 NaN   United States
# 2                 NaN   United States
# 3                 NaN   United States
# 8                 NaN   United States
# 9                 NaN   United States
# ...               ...             ...
# 355114            NaN   United States
# 355115            NaN   United States
# 355116            NaN  United Kingdom
# 355117            NaN   United States
# 355118            NaN  United Kingdom
#
# [243328 rows x 22 columns]

# %%
df5.drop_duplicates(subset='track_id', keep='first', inplace=True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255096 entries, 0 to 355118
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          255096 non-null  object
#  1   track_name        255096 non-null  object
#  2   track_genre       255096 non-null  object
#  3   artist_name       255096 non-null  object
#  4   track_popularity  255096 non-null  float64
#  5   popular_year      1863 non-null    float64
#  6   Top100            1863 non-null    object
#  7   key               255096 non-null  float64
#  8   acousticness      255096 non-null  float64
#  9   danceability      255096 non-null  float64
#  10  duration_ms       255096 non-null  float64
#  11  energy            255096 non-null  float64
#  12  instrumentalness  255096 non-null  float64
#  13  liveness          255096 non-null  float64
#  14  loudness          255096 non-null  float64
#  15  modality          255096 non-null  float64
#  16  speechiness       255096 non-null  float64
#  17  tempo             255096 non-null  float64
#  18  time_signature    255096 non-null  float64
#  19  valence           255096 non-null  float64
#  20  second_artist     24125 non-null   object
#  21  country_mb        183310 non-null  object
# dtypes: float64(15), object(7)
# memory usage: 44.8+ MB

# %%
display(df5.loc[(df5['country_mb'].notnull()) & (df5['artist_name'] == 'Drake') & (df5['country_mb'] != 'Canada')])
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, track_genre, artist_name, track_popularity, popular_year, Top100, key, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, modality, speechiness, tempo, time_signature, valence, second_artist, country_mb]
# Index: []
#
# [0 rows x 22 columns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255096 entries, 0 to 355118
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          255096 non-null  object
#  1   track_name        255096 non-null  object
#  2   track_genre       255096 non-null  object
#  3   artist_name       255096 non-null  object
#  4   track_popularity  255096 non-null  float64
#  5   popular_year      1863 non-null    float64
#  6   Top100            1863 non-null    object
#  7   key               255096 non-null  float64
#  8   acousticness      255096 non-null  float64
#  9   danceability      255096 non-null  float64
#  10  duration_ms       255096 non-null  float64
#  11  energy            255096 non-null  float64
#  12  instrumentalness  255096 non-null  float64
#  13  liveness          255096 non-null  float64
#  14  loudness          255096 non-null  float64
#  15  modality          255096 non-null  float64
#  16  speechiness       255096 non-null  float64
#  17  tempo             255096 non-null  float64
#  18  time_signature    255096 non-null  float64
#  19  valence           255096 non-null  float64
#  20  second_artist     24125 non-null   object
#  21  country_mb        183310 non-null  object
# dtypes: float64(15), object(7)
# memory usage: 44.8+ MB

# %%
df5 = df5.rename(columns = {'country_mb':'artist_country'})

# %% [markdown]
# NellySongs = df3.loc[df3.art_name == 'Drake']
# NellySongs.track_name_x.value_counts()

# %% [markdown]
# RideWitMe = NellySongs.loc[NellySongs.track_name_x == 'Headlines']
# print(RideWitMe)
# #RideWitMe

# %% [markdown]
# RideWitMe.drop_duplicates(subset='track_id', keep='first', inplace=True)
# #print(RideWitMe2)
# print(RideWitMe)

# %%
#AudioFeatures3 = pd.DataFrame(AudioFeatures2)

# %% [markdown]
# from pathlib import Path
# filepath = Path('/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/AllCharts 2000-2021 with Audio Features.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# df5.to_csv(filepath)

# %% [markdown]
# sp.audio_features('spotify:track:6naxalmIoLFWR0siv8dnQQ')[0]

# %% [markdown]
# #### write to CSV
# from pathlib import Path
# filepath = Path('/Users/gregwelliver/Desktop/springboard_files/Capstone Two - Music/Data/Merged_Data3.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# df5.to_csv(filepath)
