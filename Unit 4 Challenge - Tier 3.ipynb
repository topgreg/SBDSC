# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 

import pandas as pd
import numpy as np


# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# for web scraping
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
#properties.head()
#properties.info()
#properties.shape
#properties.index
#print(properties)
#properties.dtypes
#print(properties)
#properties['nbrnaliv'].replace([8], np.nan, inplace=True)
#properties.replace({'': '1'}, inplace=True)
#properties['Unnamed: 0'].fillna("missing")
print(properties)
# Out:
#     Unnamed: 0 City of London Barking & Dagenham        Barnet        Bexley  \
# 0          NaT      E09000001          E09000002     E09000003     E09000004
# 1   1995-01-01    91448.98487         50460.2266   93284.51832   64958.09036
# 2   1995-02-01    82202.77314        51085.77983   93190.16963   64787.92069
# 3   1995-03-01    79120.70256        51268.96956   92247.52435   64367.49344
# 4   1995-04-01    77101.20804        53133.50526   90762.87492   64277.66881
# ..         ...            ...                ...           ...           ...
# 328 2022-04-01   842758.40961       336872.40725  590638.40858  387431.61795
# 329 2022-05-01   813520.74676       338983.75876  597510.51644  386861.33254
# 330 2022-06-01   840302.71474       347835.52623  603261.46212  390232.14841
# 331 2022-07-01   820438.51245       352359.05665  601111.39405  396541.15377
# 332 2022-08-01    810105.5166       354051.98905  608725.72939  404141.23999
#
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# NOT PART OF SOLUTION
#properties.iloc[0].astype("DateTimeIndex") # attempt to set this row to a datetimeindex before making it the columns headers

# %%
#properties2 = properties[1:]
#properties2.head()
properties2 = properties.transpose() # transpose the dataframe
properties2 = properties2.iloc[:,1:] # get rid of the ID column because it isn't useful
properties2.iloc[0].astype("string") # attempt to set this row to a string before making it the columns headers
properties2.columns = properties2.iloc[0] # set first row as column headers
properties2 = properties2.reset_index() # reset index
properties3 = properties2.iloc[1:] # get rid of first row since we have set it as column headers

properties3.head()


# QUESTION - how do I change the name of the column header for the index
# QUESTION - is there a more efficient (e.g. one line) way to remove 1) the row of data that has "E09..." and 2) the row of dates after I set the column names to the dates
# QUESTION - could I have done this transformation without doing properties1, properties2, properties3, etc.? is this bad convention?
# QUESTION - how come when I use properties4.info() it only returns a very small summary, different than before I did the transformation
# QUESTION - why would we need to reset the index?

# SCRATCH ------------------------
#properties4.head()
#properties4 = properties4.reset_index(drop=False)
#properties3.info()
#print(properties3['1995-01-01 00:00:00'])

#properties2.index.values

#properties3.columns = properties2.iloc[0]
#properties3 = properties2[1:].reset_index()
#print(properties3)
#properties3.columns
# Out:
# Unnamed: 0               index 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1               City of London         91448.98487         82202.77314
# 2           Barking & Dagenham          50460.2266         51085.77983
# 3                       Barnet         93284.51832         93190.16963
# 4                       Bexley         64958.09036         64787.92069
# 5                        Brent         71306.56698         72022.26197
#
# Unnamed: 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1                  79120.70256         77101.20804         84409.14932
# 2                  51268.96956         53133.50526         53042.24852
# 3                  92247.52435         90762.87492         90258.00033
# 4                  64367.49344         64277.66881         63997.13588
# 5                  72015.76274         72965.63094         73704.04743
#
# Unnamed: 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# ...

# %%
#properties2.iloc[0].astype("string") # attempt to set this row to a string before making it the columns headers

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# CELL FOR RE-NAMING COLUMNS - remains open question, not successful doing this
#properties.columns

properties3 = properties3.rename(columns={'index':'Borough'})
properties3.head()


# QUESTION: how do I get rid of the 'NaT'
# QUESTION: what is the best practice for datetimes?
# Out:
# Unnamed: 0             Borough 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1               City of London         91448.98487         82202.77314
# 2           Barking & Dagenham          50460.2266         51085.77983
# 3                       Barnet         93284.51832         93190.16963
# 4                       Bexley         64958.09036         64787.92069
# 5                        Brent         71306.56698         72022.26197
#
# Unnamed: 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1                  79120.70256         77101.20804         84409.14932
# 2                  51268.96956         53133.50526         53042.24852
# 3                  92247.52435         90762.87492         90258.00033
# 4                  64367.49344         64277.66881         63997.13588
# 5                  72015.76274         72965.63094         73704.04743
#
# Unnamed: 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties3_melted = properties3.melt(id_vars=['Borough'])
properties3_melted = properties3_melted.rename(columns={'value':'Average_price'})
properties3_melted = properties3_melted.rename(columns={'Unnamed: 0':'Date'})
properties3_melted.dtypes
# Out:
# Borough                  object
# Date             datetime64[ns]
# Average_price            object
# dtype: object

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# cell for converting average prices to floating point numbers
#properties3.info()
# convert all of the average price columns to floats:
for column in properties3_melted.columns[2:]:
    if properties3_melted[column].dtype == 'object':
        properties3_melted[column] = properties3_melted[column].astype(float)

print(properties3_melted)

#SCRATCH ---------------
#properties3.head()
#print(properties3.iloc[:, 1])
#properties3_melted.dtypes
# Out:
#                   Borough       Date  Average_price
# 0          City of London 1995-01-01    91448.98487
# 1      Barking & Dagenham 1995-01-01    50460.22660
# 2                  Barnet 1995-01-01    93284.51832
# 3                  Bexley 1995-01-01    64958.09036
# 4                   Brent 1995-01-01    71306.56698
# ...                   ...        ...            ...
# 15931              LONDON 2022-08-01   552755.27026
# 15932          SOUTH EAST 2022-08-01   406980.66404
# 15933          SOUTH WEST 2022-08-01   335927.47192
# 15934         Unnamed: 47 2022-08-01            NaN
# 15935             England 2022-08-01   315964.75986
#
# [15936 rows x 3 columns]

# %%
#QUESTION: attempt at reducing decimal places in Average_price to 1
#properties3['Average_price'] = properties3_melted.loc[:,'Average_price'].round(decimals=1)
#print(properties3_melted)

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# Remove columns with nulls
properties4_melted = properties3_melted.dropna()
print(properties4_melted)
#properties4_melted.info()
#properties4_melted.value_counts()

# after removing the rows that contain nulls, we now have 48 rows in the data set, each representing a borough.
# however, we know that there should only be 32 boroughs, therefore we need to remove 16.  the way to do this would be to find a list of the correct boroughs, and remove any values that are not in that list
# Out:
#                   Borough       Date  Average_price
# 0          City of London 1995-01-01    91448.98487
# 1      Barking & Dagenham 1995-01-01    50460.22660
# 2                  Barnet 1995-01-01    93284.51832
# 3                  Bexley 1995-01-01    64958.09036
# 4                   Brent 1995-01-01    71306.56698
# ...                   ...        ...            ...
# 15930     EAST OF ENGLAND 2022-08-01   364885.04444
# 15931              LONDON 2022-08-01   552755.27026
# 15932          SOUTH EAST 2022-08-01   406980.66404
# 15933          SOUTH WEST 2022-08-01   335927.47192
# 15935             England 2022-08-01   315964.75986
#
# [14940 rows x 3 columns]

# %%
# cell for importing a list of boroughs
#Use pandas' `read_html` method to read the table from the URL below

london_boroughs = pd.read_html('https://en.wikipedia.org/wiki/London_boroughs')
london_boroughs = (london_boroughs[2])
london_boroughs = london_boroughs['London borough']

london_boroughs.replace(to_replace='\[.*\]', value='', regex=True, inplace=True)
london_boroughs.replace(to_replace='Hammersmith', value='Hammersmith & Fulham', regex=True, inplace=True)
london_boroughs.replace(to_replace='Kensington and Chelsea', value='Kensington & Chelsea', regex=True, inplace=True)
london_boroughs.replace(to_replace='Barking', value='Barking & Dagenham', regex=True, inplace=True)
print(london_boroughs)


#SCRATCH ---------------
#print(london_boroughs2['London borough'])

#print(london_boroughs2)
#print(london_boroughs.sort_values(['1'],ascending=True))
#print(london_boroughs)
#london_boroughs.columns()
#london_boroughs.info()
#london_boroughs2 = london_boroughs.replace(to_replace='\[.*\]', value='', regex=True, inplace=True)
#london_boroughs = london_boroughs.replace(to_replace="[", value=" ")
# boroughs_url = ('https://en.wikipedia.org/wiki/London_boroughs')
# london_boroughs = pd.read_html(boroughs_url)
# print(london_boroughs)

# london_boroughs = pd.read_html('https://en.wikipedia.org/wiki/London_boroughs')
# london_boroughs2 = (london_boroughs[2])
# london_boroughs3 = london_boroughs2['London borough']
#type(london_boroughs2)
# Out:
# 0                   Camden
# 1                Greenwich
# 2                  Hackney
# 3     Hammersmith & Fulham
# 4                Islington
# 5     Kensington & Chelsea
# 6                  Lambeth
# 7                 Lewisham
# 8                Southwark
# 9            Tower Hamlets
# 10              Wandsworth
# 11             Westminster
# 12      Barking & Dagenham
# 13                  Barnet
# 14                  Bexley
# 15                   Brent
# 16                 Bromley
# 17                 Croydon
# 18                  Ealing
# 19                 Enfield
# 20                Haringey
# 21                  Harrow
# 22                Havering
# 23              Hillingdon
# 24                Hounslow
# 25    Kingston upon Thames
# 26                  Merton
# 27                  Newham
# 28               Redbridge
# 29    Richmond upon Thames
# 30                  Sutton
# 31          Waltham Forest
# Name: London borough, dtype: object

# %%
#cell for removing the extra boroughs that aren't real London boroughs
properties5_melted = (properties4_melted['Borough'].isin(london_boroughs))
properties6_melted = properties4_melted[properties5_melted == True]
print(properties6_melted)


#SCRATCH ---------------
#print(properties4.loc[:,"index"])
#print(properties4.iloc[:,0])
#ski_data.loc[ski_data.state == 'Montana', ['AdultWeekend', 'AdultWeekday']]
#properties4 = properties3[properties.query('index not in 'london_boroughs''')]
#properties5.head()
#print(properties4)
#print(properties4.loc[:,"index"])
#print(properties4.iloc[:,0])
#print(properties4['index'])
# Out:
#                   Borough       Date  Average_price
# 1      Barking & Dagenham 1995-01-01    50460.22660
# 2                  Barnet 1995-01-01    93284.51832
# 3                  Bexley 1995-01-01    64958.09036
# 4                   Brent 1995-01-01    71306.56698
# 5                 Bromley 1995-01-01    81671.47692
# ...                   ...        ...            ...
# 15916              Sutton 2022-08-01   446106.79905
# 15917       Tower Hamlets 2022-08-01   493330.14981
# 15918      Waltham Forest 2022-08-01   524277.09279
# 15919          Wandsworth 2022-08-01   656762.17930
# 15920         Westminster 2022-08-01   964078.73061
#
# [10624 rows x 3 columns]

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
print(properties6_melted.loc[properties4_melted.Borough == 'Bexley', 'Average_price'])
# Out:
# 3         64958.09036
# 51        64787.92069
# 99        64367.49344
# 147       64277.66881
# 195       63997.13588
#              ...
# 15699    387431.61795
# 15747    386861.33254
# 15795    390232.14841
# 15843    396541.15377
# 15891    404141.23999
# Name: Average_price, Length: 332, dtype: float64

# %%
x = properties6_melted.loc[properties6_melted.Borough == 'Kensington & Chelsea', 'Date']
y = properties6_melted.loc[properties6_melted.Borough == 'Kensington & Chelsea', 'Average_price']

#QUESTION - why did the above work, but not these two:
# x = properties4_melted.loc[properties4_melted.Borough == 'Barnet', ['Date']]
# y = properties4_melted.loc[properties4_melted.Borough == 'Barnet', ['Average_price']]

plt.plot(x, y)
plt.xlabel("Date")  # add X-axis label
plt.ylabel("Price")  # add Y-axis label
plt.title("Time series of average prices")  # add title
plt.show()



#SCRATCH ---------------

# original working that used .iloc instead of ability to input a row name
# working v1 - would need to re-do this since I re-indexed the dataframe, as well as removed the NaT column
# x = properties6.columns[2:]
# y = properties6.iloc[3]
# y = y[2:]
# print(x)

#result = df.loc["Stuti"]
#y = properties6.iloc[[3], [2]]
#df.loc[["x", "y"]]
#y = properties6.loc[properties6 == 'Ealing']

#properties6[properties6['index'] == 'Brent']
#properties7.loc['Brent']
# properties7_melted = properties6_melted.set_index('Borough')
# properties7_melted = properties7_melted.iloc[:,1:]

#x = properties4_melted.columns['Date']
#print(properties4_melted.loc['Croydon'])

#properties4_melted.loc[properties4_melted.Borough == 'Barnet', ['Date', 'Average_price']]
#properties4_melted.loc[properties4_melted.Borough == 'Barnet', 'Average_price']

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#As you can see below, I tried doing this a variety of ways.  Ultimately I didn't try the lambda function since I was having issues with the timestamp nature of the Date column, as this preventd me from taking certain actions on the data

# %%
# NOT PART OF THE SOLUTION

#properties6_melted.dtypes

#cell for trying to convert the Date column so it doesn't have the timestamp issue
# for column in properties6_melted.columns[0:]:
#     if properties6_melted[column].dtype == 'datetime64[ns]':
#         properties6_melted[column] = properties6_melted[column].astype('date')

# properties6_melted.dtypes

# %%
# NOT PART OF THE SOLUTION
# for item in properties6_melted['Date']:
#     item = item.astype('string')
#     #print(item)
#     #      item = item.astype('string')
#         #properties3_melted[column] = properties3_melted[column].astype(float)

# properties6_melted.dtypes

# %%
properties6_melted['Date'] = pd.to_datetime(properties6_melted['Date']).dt.date
# Question: why did this code change the Date column to an 'object' data type, rather than a date?
# Question: what is the most efficient way to change the data type from datetime64[ns] to a date? had some trouble with this
# Out:
# /var/folders/rc/20gvvbw10mg1xrcm82p5g4tm0000gn/T/ipykernel_35291/1010925022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties6_melted['Date'] = pd.to_datetime(properties6_melted['Date']).dt.date

# %%
properties6_melted['Date_string'] = properties6_melted['Date'].astype('string')
properties6_melted['Year'] = properties6_melted['Date_string'].str[:4]

properties6_melted.head(20)

# QUESTION: is there a more efficient way to do this? I was concerned about changing the Date column to a string, because I wanted to preserve the sorting capabilities
# Out:
# /var/folders/rc/20gvvbw10mg1xrcm82p5g4tm0000gn/T/ipykernel_35291/115975525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties6_melted['Date_string'] = properties6_melted['Date'].astype('string')
# /var/folders/rc/20gvvbw10mg1xrcm82p5g4tm0000gn/T/ipykernel_35291/115975525.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties6_melted['Year'] = properties6_melted['Date_string'].str[:4]
#                  Borough        Date  Average_price Date_string  Year
# ...

# %%
# NOT PART OF THE SOLUTION

# doesn't seem necessary, perhaps come back to this
#properties6_melted.dtypes

# for item in properties6_melted['Date']:
#      item = item.astype('string')
        #properties3_melted[column] = properties3_melted[column].astype(float)


# for item in properties6_melted['Date']:
#      print(item[0:3])
#         properties3_melted[column] = properties3_melted[column].astype(float)

#print(properties3_melted)

# doesn't seem necessary, perhaps come back to this

# for column in properties3_melted.columns[2:]:
#     if properties3_melted[column].dtype == 'object':
#         properties3_melted[column] = properties3_melted[column].astype(float)

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# NOT PART OF THE SOLUTION
#cell with previous trash efforts

#melted_data = properties6_melted

# def create_price_ratio(borough):
#     year_and_price = [properties6_melted.loc[properties6_melted.Borough == 'Camden', ['Year', 'Average_price']]] # this returns all of the prices for the borough that is passed in
#     #year_and_price = year_and_price[1:]
#     #prices_1995 = []
#     #year = year_and_price[0]
#     #price = year_and_price[1]
#     #print(year_and_price)
#     #for row in year_and_price:
#         #print(row)
#         #year = row.iloc[:,0]
#         #price = row.iloc[:,1]
#         #print(year_and_price.loc[year_and_price['Year']])
# #         if 'Year' == '1995':
# #             print('yes')
# #         else:
# #             print('not yet')


#---------------


# def create_price_ratio(borough):
#     for row in [melted_data.loc[melted_data.Borough == borough]]:
#         if melted_data.loc[melted_data.Year] == '1995':
#             print(row)


# create_price_ratio('Camden')

#melted_data.loc[melted_data.Year == '1995']

#-------------------

# %%
# working 1 borough

melted_data = properties6_melted

def create_price_ratio(borough):
    data = melted_data.loc[melted_data.Borough == borough] # subset data on the borough that is passed in the argument
    price_1995 = data.query('Year== "1995"')
    price_1995 = pd.DataFrame(price_1995)
    avg_price_1995 = price_1995['Average_price'].mean()
    price_2018 = data.query('Year== "2018"')
    price_2018 = pd.DataFrame(price_2018)
    avg_price_2018 = price_2018['Average_price'].mean()
    appreciation_ratio = avg_price_2018 / avg_price_1995
#     print(avg_price_1995)
#     print(avg_price_2018)
#     print(appreciation_ratio)
    return appreciation_ratio


final_ratio = create_price_ratio('Camden')
print(final_ratio)



#[melted_data.loc[melted_data.Borough == 'Camden']]
# Out:
# 6.9986573351270716

# %%
# working multiple boroughs
melted_data = properties6_melted


london_boroughs_list = list(london_boroughs)
#print(london_boroughs_list)


def create_price_ratio(borough):
    data = melted_data.loc[melted_data.Borough == borough] # subset data on the borough that is passed in the argument
    price_1995 = data.query('Year== "1995"')
    price_1995 = pd.DataFrame(price_1995)
    avg_price_1995 = price_1995['Average_price'].mean()
    price_2018 = data.query('Year== "2018"')
    price_2018 = pd.DataFrame(price_2018)
    avg_price_2018 = price_2018['Average_price'].mean()
    appreciation_ratio = avg_price_2018 / avg_price_1995
#     print(avg_price_1995)
#     print(avg_price_2018)
#     print(appreciation_ratio)
    return borough, appreciation_ratio


#final_ratio = create_price_ratio("Camden", "Bexley")
#print(final_ratio)

final_list1 = [create_price_ratio(borough) for borough in london_boroughs_list]
final_list2 = pd.DataFrame(final_list1)
final_list2.columns = ['Borough', 'Ratio']

#final_list3 = final_list2.rename(columns={'1':'Ratio'})
#print(final_list2)

final_list_sorted = final_list2.sort_values(by=['Ratio'], ascending=False)
print(final_list_sorted)
                                                
#print(final_list_sorted)
#print(final_list2)
# Out:
#                  Borough     Ratio
# 2                Hackney  8.249069
# 8              Southwark  7.846794
# 11           Westminster  7.629824
# 6                Lambeth  7.510920
# 31        Waltham Forest  7.194183
# 5   Kensington & Chelsea  7.071967
# 9          Tower Hamlets  7.014665
# 0                 Camden  6.998657
# 7               Lewisham  6.990772
# 20              Haringey  6.887750
# 4              Islington  6.800519
# 15                 Brent  6.748548
# 10            Wandsworth  6.716822
# 27                Newham  6.578609
# 26                Merton  6.363840
# 1              Greenwich  6.126292
# 25  Kingston upon Thames  6.000689
# 29  Richmond upon Thames  5.939138
# 18                Ealing  5.910593
# 3   Hammersmith & Fulham  5.887188
# 28             Redbridge  5.822378
# 13                Barnet  5.809476
# 12    Barking & Dagenham  5.696801
# 21                Harrow  5.578428
# 23            Hillingdon  5.562496
# 19               Enfield  5.509980
# ...

# %%
#melted_data.loc[melted_data.Year == '2018', ['Borough', 'Average_price']] # this returns all of the prices for the borough that is passed in
prices_2018 = melted_data.loc[melted_data.Date_string == '2018-12-01', ['Borough', 'Average_price', 'Date']]
prices_2018_sorted = prices_2018.sort_values('Average_price', ascending=False)
print(prices_2018_sorted)
# Out:
#                     Borough  Average_price        Date
# 13795  Kensington & Chelsea   1.345805e+06  2018-12-01
# 13808           Westminster   9.650226e+05  2018-12-01
# 13782                Camden   8.677953e+05  2018-12-01
# 13788  Hammersmith & Fulham   7.333597e+05  2018-12-01
# 13802  Richmond upon Thames   6.457449e+05  2018-12-01
# 13794             Islington   6.251900e+05  2018-12-01
# 13807            Wandsworth   5.955038e+05  2018-12-01
# 13787               Hackney   5.481349e+05  2018-12-01
# 13789              Haringey   5.448365e+05  2018-12-01
# 13778                Barnet   5.338101e+05  2018-12-01
# 13799                Merton   5.176128e+05  2018-12-01
# 13797               Lambeth   5.109218e+05  2018-12-01
# 13803             Southwark   5.016045e+05  2018-12-01
# 13796  Kingston upon Thames   4.864013e+05  2018-12-01
# 13784                Ealing   4.819219e+05  2018-12-01
# 13780                 Brent   4.763556e+05  2018-12-01
# ...

# %%
# NOT PART OF SOLUTION
#----------

# ---- one Borough at a time
# working to select based on two criteria: properties6_melted[(properties6_melted['Borough'] == 'Camden') & (properties6_melted["Year"] == '1995')]
# had trouble with the next line of code trying to return both the 1995 and 2018 data
#year_borough_subset_1995 = properties6_melted[(properties6_melted['Borough'] == 'Camden') & (properties6_melted["Year"] == '1995')]

#Average_1995 = year_borough_subset_1995['Average_price'].mean()
#print(Average_1995)
#print(year_borough_subset)

#properties6_melted[(properties6_melted['Borough'] == 'Camden') & (properties6_melted["Year"] == '1995')]

#properties6_melted.dtypes

# ---- multiple boroughs - tried using 'groupby' but didn't get it working
#working: year_borough_subset_1995_2 = properties6_melted[(properties6_melted["Year"] == '1995')]
#working 1 year: year_borough_subset_1995_2 = properties6_melted[properties6_melted["Year"] == '1995']

# this code gets error "TypeError: unhashable type: 'Series'" :  year_borough_subset_1995_2 = properties6_melted.groupby('Borough')[[properties6_melted["Year"] == '1995']]

# year_borough_subset_1995_2 = properties6_melted[properties6_melted["Year"] == '1995'].mean()
#print(year_borough_subset_1995_2)


#year_borough_subset_1995_2 = properties6_melted.groupby('Borough')[['Year'] == '1995']


#properties6_melted.groupby('Borough')
#print(properties6_melted)
#print(grouped)

#properties6_melted[properties6_melted['Region'] != properties6_melted['state']].groupby('Borough')['Year'].value_counts()
#properties6_melted.groupby('Borough')['Year'].mean()


#----------








#print(properties7.loc['Croydon'].mean())
#properties7['1995-02-01'].loc['Croydon'].mean()
#properties7.loc[:, 'index']
#properties7.loc['Croydon'].mean()

#note to self: none of the column calls are working with properties 7; I'll test on properties 6 to see how to do the date/time calls
#another way to get all of the indices to mean would be to just use iloc; but that could get problematic when I need to start selecting years, so want to figure that out

#properties6.loc[:, '1995-01-01 00:00:00']
#properties6['1995-01-01 00:00:00']

#print(properties6.columns.tolist())


#properties7[['1995-01-01 00:00:00', '1995-02-01 00:00:00']].mean(axis=0)
#properties7.columns


#df[['b', 'c']].iloc[[2,4]].mean(axis=0)



# ---
# calculate the ratio of prices in the last month of the dataset, and first month
#properties7.iloc[:,0] # first column
#properties7.iloc[:,331] # last column

#this is working:
#ratio_of_prices = properties7.iloc[:,331] / properties7.iloc[:,0]
#print(ratio_of_prices)


# QUESTION - how do this with using the timestamps or datetime

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# Answer:
#
# Boroughs with the greatest price appreciation (ratios included)
# 1. Hackney: 8.24
# 2. Southwark: 7.84
# 3. Westminster: 7.62
#
# Boroughs with the lowest price appreciation (ratios included)
# 1. Bexley: 5.32
# 2. Croydon: 5.37
# 3. Sutton: 5.39
